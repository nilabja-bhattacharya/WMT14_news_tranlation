# %% [markdown]
# <a href="https://colab.research.google.com/github/nilabja-bhattacharya/WMT14_news_tranlation/blob/master/Copy_of_seq_seq_and_attention_based_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)

# %%
path = "/gdrive/My Drive/"

# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
import torch.utils.data as Data

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Language Model from input and output sentences

# %%
SOS_token = 0
EOS_token = 1
UNK_token = 2


class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS", 2:"UNK"}
        self.n_words = 3  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %%
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
#     s = re.sub(r"([.!?|])", r" \1", s)
    #s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    return s

# %%
  def readLangs(lang1, lang2, reverse=False):
    print("Reading lines...")

    # Read the file and split into lines
#     lines = open('%s-%s.txt' % (lang1, lang2), encoding='utf-8').\
#         read().strip().split('\n')
    lines1 = open(path+"corpus/training/hindien-train.tok."+lang1).readlines()
    lines2 = open(path+"corpus/training/hindien-train.tok."+lang2).readlines()
    #print(lines)
    # Split every line into pairs and normalize
    pairs = [[normalizeString(x), normalizeString(y)] for (x,y) in zip(lines1, lines2)]
#     pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
#     print(pairs[:50])
    # Reverse pairs, make Lang instances
    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)

    return input_lang, output_lang, pairs

# %%
MAX_LENGTH = 100

def filterPair(p):
    return len(p[0].split(' ')) < MAX_LENGTH and \
        len(p[1].split(' ')) < MAX_LENGTH


def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# %%
def prepareData(lang1, lang2, reverse=False):    
    input_lang, output_lang, pairs = readLangs(lang1, lang2, reverse)
    #print(input_lang, output_lang, pairs)
    print("Read %s sentence pairs" % len(pairs))
    pairs = filterPairs(pairs)
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    for pair in pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    return input_lang, output_lang, pairs

input_lang, output_lang, pairs = prepareData('en', 'hi', True)
#print(input_lang, output_lang, pairs)
print(random.choice(pairs))

# %% [markdown]
# ## Encoder

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.embedding = nn.Embedding(input_size, hidden_size)
        #changes
        self.gru = nn.LSTM(hidden_size, hidden_size, num_layers, bidirectional=True)

    def forward(self, input, hidden, cell):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        output, (hidden, cell) = self.gru(output, (hidden, cell))
        return output, hidden, cell

    def initHidden(self):
        return torch.zeros(self.num_layers*2, 1, self.hidden_size, device=device)

# %% [markdown]
# ## Decoder

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, num_layers):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.embedding = nn.Embedding(output_size, hidden_size)
        #changes
        self.gru = nn.LSTM(hidden_size, hidden_size, num_layers, bidirectional=True)
        self.out = nn.Linear(hidden_size*2, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden, cell):
        output = self.embedding(input).view(1, 1, -1)
        output = F.relu(output)
        output, (hidden, cell) = self.gru(output, (hidden, cell))
        output = self.softmax(self.out(output[0]))
        return output, hidden, cell

    def initHidden(self):
        return torch.zeros(self.num_layers*2, 1, self.hidden_size, device=device)

# %% [markdown]
# ## Attention Based Decoder

# %%
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, num_layers,  dropout_p=0.1, max_length=MAX_LENGTH):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length
        self.num_layers = num_layers
        self.embedding = nn.Embedding(self.output_size, self.hidden_size*2)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size *4 , self.hidden_size)
        self.attn_general = nn.Linear(self.max_length, self.max_length)
        self.attn_concat = nn.Linear(self.hidden_size*3, self.max_length)
        self.lcl_wa_into_hs = nn.Linear(self.hidden_size*2,self.hidden_size*2)
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.LSTM(self.hidden_size, self.hidden_size, self.num_layers, bidirectional=True)
        self.out = nn.Linear(self.hidden_size*2, self.output_size)

    def forward(self, input, hidden, cell, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)
        #print(embedded.size(), hidden.size())
        # attn_weights = F.softmax(
        #     self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        X = None
        #print(embedded.shape, encoder_outputs.shape)
        if attention_type == 'dot':
            X = torch.matmul(embedded[0], encoder_outputs.T) #dot product
        elif attention_type == 'general':
            X = self.attn_general(torch.matmul(self.lcl_wa_into_hs(embedded[0]), encoder_outputs.T)) ## general
        elif attention_type == 'concat':
            X = self.attn_concat(torch.cat((embedded[0], hidden[0]), 1))  #concat
        attn_weights = F.softmax(X, dim = 1)
        attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                 encoder_outputs.unsqueeze(0))
        #print(attn_applied.shape)
        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)
        output, (hidden, cell) = self.gru(output, (hidden, cell))

        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, cell, attn_weights

    def initHidden(self):
        return torch.zeros(self.num_layers*2, 1, self.hidden_size, device=device)

# %%
def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] if word in lang.word2index.keys() else UNK_token for word in sentence.split(' ')]


def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    #print(indexes)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)


def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %% [markdown]
# ## Training of Neural Network

# %%
teacher_forcing_ratio = 0.5
def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()
    encoder_cell = encoder.initHidden()
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size*2, device=device)

    loss = 0

    for ei in range(input_length):
        #print(ei)
        encoder_output, encoder_hidden, encoder_cell = encoder(
            input_tensor[ei], encoder_hidden, encoder_cell)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden
    decoder_cell = encoder_cell
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            if attention == True:
                decoder_output, decoder_hidden, decoder_cell, decoder_attention = decoder(
                    decoder_input, decoder_hidden, decoder_cell, encoder_outputs)
            else:
                decoder_output, decoder_hidden, decoder_cell = decoder(
                    decoder_input, decoder_hidden, decoder_cell)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            if attention == True:
                decoder_output, decoder_hidden, decoder_cell, decoder_attention = decoder(
                    decoder_input, decoder_hidden, decoder_cell, encoder_outputs)
            else:
                decoder_output, decoder_hidden, decoder_cell = decoder(
                    decoder_input, decoder_hidden, decoder_cell)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %%
import time
import math


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %% [markdown]
# ## Gradient Descent

# %%
 def trainIters(encoder, decoder, n_iters, print_every=1000, learning_rate=0.001):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every
    # lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False
    encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=True)
    decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate,  betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=True)
    if from_checkpoint == True:
      checkpoint_encoder = torch.load(path+"checkpoint.encoder_checkpoint.attn_concat."+str(itr)+".pth")
      encoder.load_state_dict(checkpoint_encoder['model_state_dict'])
      encoder_optimizer.load_state_dict(checkpoint_encoder['optimizer_state_dict'])
      checkpoint_decoder = torch.load(path+"checkpoint.decoder_checkpoint.attn_concat."+str(itr)+".pth")
      decoder.load_state_dict(checkpoint_decoder['model_state_dict'])
      decoder_optimizer.load_state_dict(checkpoint_decoder['optimizer_state_dict'])
      epoch = checkpoint_encoder['epoch']
    
    criterion = nn.NLLLoss()

    for iter in range(itr+1, itr + n_iters + 1):
        print("Epoch:{0}".format(iter))
        training_pairs = [tensorsFromPair(random.choice(pairs))
                      for i in range(len(pairs))]
        for b in range(1,len(pairs)+1):
              training_pair = training_pairs[b-1]
              input_tensor = training_pair[0]
              target_tensor = training_pair[1]

              loss = train(input_tensor, target_tensor, encoder,
                          decoder, encoder_optimizer, decoder_optimizer, criterion)
              print_loss_total += loss
              plot_loss_total += loss
        
              if b % print_every == 0:
                  print_loss_avg = print_loss_total / (print_every)
                  print_loss_total = 0
                  plot_losses.append(print_loss_avg)
                  print('%s (%d %d%%) %.4f' % (timeSince(start, b / len(pairs)),
                                              b , b / len(pairs) * 100, print_loss_avg))

        # if iter % print_every == 0:
        #     print_loss_avg = print_loss_total / (print_every*len(pairs))
        #     print_loss_total = 0
        #     plot_losses.append(print_loss_avg)
        #     print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
        #                                  iter, iter / n_iters * 100, print_loss_avg))
        evaluateRandomly(encoder, decoder)
        torch.save({
        'epoch': iter,
        'model_state_dict': encoder.state_dict(),
        'optimizer_state_dict': encoder_optimizer.state_dict(),
        }, path+"checkpoint.encoder_checkpoint.attn_concat."+str(iter)+".pth")
        torch.save({
        'epoch': iter,
        'model_state_dict': decoder.state_dict(),
        'optimizer_state_dict': decoder_optimizer.state_dict(),
        }, path+"checkpoint.decoder_checkpoint.attn_concat."+str(iter)+".pth")

    #showPlot(plot_losses)
    return plot_losses

# %%
import matplotlib.pyplot as plt
plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np


def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

# %% [markdown]
# ## Evaluation of test data

# %%
def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()
        encoder_cell = encoder.initHidden()
        encoder_outputs = torch.zeros(max_length, encoder.hidden_size*2, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden, encoder_cell = encoder(input_tensor[ei],
                                                     encoder_hidden, encoder_cell)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden
        decoder_cell = encoder_cell

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            if attention == True:
                decoder_output, decoder_hidden, decoder_cell, decoder_attention = decoder(
                    decoder_input, decoder_hidden, decoder_cell, encoder_outputs)
                decoder_attentions[di] = decoder_attention.data
            else:
                decoder_output, decoder_hidden, decocer_cell = decoder(
                    decoder_input, decoder_hidden, decoder_cell)
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == UNK_token:
                decoded_words.append('<UNK>')
            if topi.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_lang.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words, decoder_attentions[:di + 1]

# %%
from nltk.translate import bleu
from nltk.translate.bleu_score import sentence_bleu
from nltk.translate.bleu_score import SmoothingFunction

def calculate_bleu(pred_trg, real_trg):   
    smoothie = SmoothingFunction().method4
    return sentence_bleu(real_trg, pred_trg, smoothing_function=smoothie)
    # smoothie = SmoothingFunction().method4
    # return bleu(real_trg, pred_trg, smoothing_function=smoothie)
def evaluateRandomly(encoder, decoder, n=10):
    for i in range(n):
        pair = random.choice(pairs)
        print('>', pair[0])
        print('=', pair[1])
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        print('<', output_sentence)
        print('')
        print(calculate_bleu(pair[1], output_words))

# %%
def showAttention(input_sentence, output_words, attentions):
    # Set up figure with colorbar
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(attentions.numpy()[:20][:20], cmap='bone')
    fig.colorbar(cax)

    # Set up axes
    ax.set_xticklabels([''] + input_sentence.split(' ') +
                       ['<EOS>'], rotation=90)
    ax.set_yticklabels([''] + output_words)

    # Show label at every tick
    ax.xaxis.set_major_locator(ticker.MultipleLocator(2))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(2))

    plt.show()

def evaluateAndShowAttention(encoder, decoder, input_sentence, real_output_sentence):
    output_words, attentions = evaluate(
        encoder, decoder, input_sentence)
    output_sentence = ' '.join(output_words)
    # print('input =', input_sentence)
    # print('output =', ' '.join(output_words))
    print('>', input_sentence)
    print('=', real_output_sentence)
    print('<', output_sentence)
    print('')
    blu = calculate_bleu(real_output_sentence, output_words)
    # if attention == True:
    #   showAttention(input_sentence, output_words, attentions)
    return blu


def evaluate_on_test(encoder, decoder):
  trg = open(path+"corpus/hindien-dev.tok.hi").readlines()
  real_out = open(path+"corpus/hindien-dev.tok.en").readlines()
  blu = 0
  for t, r in zip(trg[:1000], real_out[:1000]):
      t = t.replace('\n','')
      r = r.replace('\n', '')
      if len(t.split(' ')) < MAX_LENGTH and len(r.split(' ')) < MAX_LENGTH:
          blu += evaluateAndShowAttention(encoder, decoder, t, r)
  return blu/len(trg[:1000])

# %% [markdown]
# ## Paper 1 implementation:
#
# Here I'm using a sequence to sequence encoder decoder model of GRU with 256 hidden units.
#
# Encoder converts the input sequences to a normalized vector space and then decoder unit interpret the output sentence from this normalized vector space.
#
# I'm running the code for 50000 iterations.

# %%
from_checkpoint = True
save_checkpoint = True
itr = 2

# %%
# hidden_size = 256
# num_layers = 1
# attention = False
# torch.cuda.empty_cache() 
# encoder1 = EncoderRNN(input_lang.n_words, hidden_size, num_layers).to(device)
# decoder1 = DecoderRNN(hidden_size, output_lang.n_words, num_layers).to(device)
# losses = trainIters(encoder1, decoder1, 1, print_every=1000)

# %%
#  showPlot(losses)

# %%
if from_checkpoint == True:
      checkpoint_encoder = torch.load(path+"checkpoint.encoder_checkpoint.attn_concat."+str(itr)+".pth")
      encoder1.load_state_dict(checkpoint_encoder['model_state_dict'])
      checkpoint_decoder = torch.load(path+"checkpoint.decoder_checkpoint.attn_concat."+str(itr)+".pth")
      decoder1.load_state_dict(checkpoint_decoder['model_state_dict'])

# %%
# blu = evaluateRandomly(encoder1, decoder1)
# print(blu)

# %%
# blu = evaluate_on_test(encoder1, decoder1)
# print(blu)

# %% [markdown]
# ## Attention Based Models

# %% [markdown]
# ### DOT variant

# %%
# hidden_size = 256
# num_layers = 1
# attention = True
# attention_type = 'dot'
# encoder1 = EncoderRNN(input_lang.n_words, hidden_size, num_layers).to(device)
# decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, num_layers, dropout_p=0.1).to(device)
# losses = trainIters(encoder1, decoder1, 2, print_every=1)

# %%
#  showPlot(losses)

# %%
# evaluateRandomly(encoder1, decoder1)

# %%
# # blu = evaluate_on_test(encoder1, decoder1)
# print(blu)

# %% [markdown]
# ### General Variant

# %%
# hidden_size = 1
# num_layers = 2
# attention = True
# attention_type = 'general'
# encoder1 = EncoderRNN(input_lang.n_words, hidden_size, num_layers).to(device)
# decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, num_layers, dropout_p=0.1).to(device)
# losses = trainIters(encoder1, decoder1, 100000, print_every=10)

# %%
#  showPlot(losses)

# %%
# evaluateRandomly(encoder1, decoder1)

# %%
# # blu = evaluate_on_test(encoder1, decoder1)
# print(blu)

# %% [markdown]
# ### Concat Varient

# %%
hidden_size = 256
num_layers = 1
attention_type = 'concat'
attention = True
encoder1 = EncoderRNN(input_lang.n_words, hidden_size, num_layers).to(device)
decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, num_layers, dropout_p=0.1).to(device)
# losses = trainIters(encoder1, decoder1, 1, print_every=1000)

# %%
 showPlot(losses)

# %%
torch.save(losses, 'losses_concat.pth')

# %%
evaluateRandomly(encoder1, decoder1)
# Out:
# > यह गण अत   यधिक आर  थिक महत   व का ह क  योकि य खतो म फसलो का सत   यानाश कर दत ह , अन   न क भडारो तथा कच   च और तयार माल को खराब कर दत ह .
# = the order is of great economic importance , because they destroy crops in the field , spoil stored grains and various other raw and manufactured goods .
# < this is , , , , , , , , , and , , and , , and , , , and , . . <EOS>
#
# 0.040221825638642
# > एक किस   म क जीवाण स दसर किस   म क जीवाण स दसर किस   म क जीवाण म विशिष  ट अभिलक  षयो का बहन करन वाला डी.एन.ए . किस प  रकार स   थानातरित किया जा सकता ह ताकि आ क गण भ  म स   थानातरित हो सक इसकी तीन अलग-अलग पद  धति प  रचलित ह .
# = three distinct ways in which dna carrying a particular genetic character may be transferred from one bacterial strain to another , thereby conferring type a qualities to type b have been discovered .
# < one of the the a a a a the the the the the the the the the the the the the the the the the the the the the the the . . <EOS>
#
# 0.03802317842736737
# > श  रणी : दश
# = . category : country .
# < category : country <EOS>
#
# 0.5223311042930855
# > भख
# = hunger
# < hunger <EOS>
#
# 1.0
# > वह पीठ क बल लट गया और अपन हाथ सिर क नीच टिका लिय ।
# = he turned over on to his back and put his hands behind his head .
# < he went out of his head and and his hand . <EOS>
#
# 0.08834915624612143
# > &#91; .... प  रोपन , गस , मिट  टी का तल , या उपभोग  य सामग  रियो का भी नही &#93;
# = &#91; ... propane , gas , kerosene or consumables &#93;
# < &#91; , , , , , , , , , , , , <EOS>
#
# 0.0647637082044514
# > चीन : २.६८०
# = china : 2.680
# < china : <EOS>
#
# 0.3026643726685863
# > जनवरी 2005 म दक  षिण अफ  रीका और इग  लड क बीच
# = in january 2005 between south africa and england .
# < to south africa and south africa in south africa <EOS>
#
# 0.1833031180398353
# > काजल
# = kohl ( cosmetics )
# < disconnected <EOS>
#
# 0.18976138485520888
# > मझ क  या करन कि जररत ह और मझ इसक बार म कब सोचना शर करना चाहिए ?
# = what do i need to do and when do i need to start thinking about this ?
# < i should i to to to to , to , to ? ? ? <EOS>
#
# 0.12569834882997358

# %%
blu = evaluate_on_test(encoder1, decoder1)
print(blu)
# Out:
# > अंतरराष ् ट ् रीय कानून में परिभाषा
# = change in International law
# < start the the of of the the <EOS>
#
# > पर मेरे यहाँ एक कहावत है
# = But there is a saying in my culture
# < and the the of of of of <EOS>
#
# > “ तब भी , जबकि तुम सिर ् फ यायावर बनना चाहते हो या किसी व ् यापारी की बेटी से शादी करना चाहते हो ! ”
# = &quot; Even when all you want to do is travel ? &lt; s &gt; Or marry the daughter of a textile merchant ? &quot;
# < &quot; he is , , &quot; , , , , , , , , , , , . . . . . . . . <EOS>
#
# > लालबहादुर शास ् त ् री
# = Lal Bahadur Shastri
# < seth de member of the prime minister <EOS>
#
# > ネットワーク名が短かすぎます
# = Network name too short
# < leave <EOS>
#
# > ब ् रिटिश काउंसिल
# = British Council
# < our the of <EOS>
#
# > मोज ़ ाम ् बीक
# = Mozambique
# < 2nd - of the members <EOS>
#
# > इसके बाद २८ मार ् च को अंतर ् राष ् ट ् रीय भारतीय फ ़ िल ् म अकादमी के एक सम ् मेलन में जब उनसे पूछा गया कि प ् रवास विरोधी मुद ् दे पर उनकी क ् या राय है तब अमिताभ ने कहा कि यह देश में किसी भी स ् थान पर रहने का एक मौलिक अधिकार है और संविधान ऐसा करने की अनुमति देता है ।
# = After that on 28th march in the meeting of international indian film academy he said that ther is a right for everybody to live any wher in India .
# < after the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the . . . . <EOS>
#
# > यह अकबर द ् वारा 1565 में बनवाया गया था ।
# = This was constructed by Akbar in the Year 1565 .
# < this was akbar akbar was akbar was a the <EOS>
#
# > मुक ् तिनाथ
# = Muktinath
# < member singh <EOS>
#
# > सभी संदेश लड ़ ी फैलाएँ
# = Expand all message threads
# < all of all of all of the <EOS>
#
# > प ् रदर ् शक पथ
# = Display path
# < 2nd character , the character <EOS>
#
# > हर एक कुएरी के बाद बफ ़ र फ ् लश करे .
# = Flush buffer after each query .
# < after the , the , the the the the the the the . . . . . . <EOS>
#
# > एक मिनट के जोखिम खेल का रोमांच जहोःं आधी सेंकिण ् ड का निर ् णय अक ् षरशः हेली स ् कीइंग को बनाया बिगाड सकता है , शायद उपमहाद ् वीप में प ् रस ् तुत होने वाला सबसे उत ् तेजक खेल है .
# = a thrill a minute adventure sport where split second decisions can literally make or mar heliskiing is probably the most excting sport to be introduced in the subcontinent .
# < the the of of the , , the , the , the , the , the , the , the , the , the , the , the , the , the , the , the , the , , , , , , . . . . . <EOS>
#
# > और इसी ने ही इस विडियो को इतना मशहूर बना दिया ।
# = that would eventually propel the video to be as popular as it would become .
# < and this &apos;s the to to . . <EOS>
#
# > चेसिंग ् टन
# = Chessington
# < simon of of <EOS>
#
# > इ-मेल वाले आवेदनपत ् रों में कृपया यह सुनिश ् चित कर लें कि यह ड़ाक द ् वारा अलग से भेजे जायें ताकि यह आवेदन पत ् र के मिलने के पाँच कार ् यकारी दिनों के अंदर पहुँच जायें .
# = For e-mail applications please ensure that these are sent separately by post to arrive within five working days of receipt of the application form .
# < the the of of of of of of the , of the of of , of the of , of the , the the of the , the the the the the the of the of the the the . . . . <EOS>
#
# > प ् रधानमंत ् री कुमारकोम के &apos; चिंतन &apos; के समय भी यही करते रहे और उनके चिंतन से निकले गद ् य को देखकर यही लगता है कि स ् थितियां गड़ेबड़े ही बनी रहेंगी .
# = The prime minister while &quot; musing &quot; in Kumarakom continues to do this and , judging by the prose that resulted from his musings , continues to get things wrong .
# < the the of of the the the the the the the the the the the the the the the the the the the the , the , the , the , . the . . . . . <EOS>
#
# > जॉर ् ज के समर ् थकों का कहना है कि यह सब अंबिका सोनी की वजह से हो रहा है , जो अब कांग ् रेस में नंबर दो की हैसियत में आ चुकी हैं .
# = George &apos; s bunch of supporters claim their leader has been done in by Ambika Soni , the new No . 2 in the Congress .
# < the the of of of , of , , , , , the , the , the , the , the , the , the , , , , , the the the the . . <EOS>
#
# > ताजा फलों का रस पानी डालकर कम संहत बनाये और उस का सेवन खाने के दौरान करें .
# = Dilute fresh fruit juice and take with meals .
# < the the the the the the the the the the the and and the and the the . . <EOS>
#
# > तब – ( हंसते हैं ) – बहुत शीतल है !
# = So -- ( Laughter ) -- so cool !
# < for the the ! ! ! ” <EOS>
#
# > हैज़र ् ड - ऐसी कोई भी वस ् तु जिस से ग ् राहक को हानि हो सकती है ।
# = A hazard is anything that may cause harm to a customer .
# < the the of of of a of , of , of , of , of the . . . <EOS>
#
# > किसी एक को देखें . . .
# = Touch one . . .
# < a was . . . . . . . . . . . . <EOS>
#
# > &apos; शावर &apos; इनका वीर तथा प ् रतापी नेता था .
# = Shanwar was their brave and powerful leader .
# < the the the the the the the the . <EOS>
#
# > लोग मानते हैं कि इनके पास जादुई शक ् ति है .
# = They are believed to have magical powers .
# < the people aged of people were to the of the . . <EOS>
#
# > 1937 में जापान ने चीन पर आक ् रमण किया ।
# = in 1937 japan attacked china .
# < the the of from the from china china china . <EOS>
#
# > परंतु मताधिकार चाहे चयनातऋ-ऊण ् श ् छ ् ष ् -मक हो या सार ् वभऋम , ढिऋर भी सभी तरह की ढेरों शासन प ् रणालियों में सबसे कम असंतोषजनक है .
# = But whether it is selective or universal suffrage , democracy still remains &apos; the least unsatisfactory of all the many forms of government &apos; .
# < the the of of of , , , , , , , , , , , , , , , , , , the , the , , , , . . <EOS>
#
# > एक औरत 6 .
# = One woman loses six .
# < once a one . <EOS>
#
# > राजनीति
# = Politics
# < politics <EOS>
#
# > पावर पफ गर ् लस
# = The Powerpuff Girls
# < guru guru devi <EOS>
#
# > &quot; अपनी मृत ् यु से पहले , मैं अन ् तर ् राष ् ट ् रीय Date रेखा पर चलना चाहता हूँ । &quot;
# = &quot; Before I die , I want to straddle the International Date Line . &quot;
# < &quot; the , the the the , the the , &quot; the , , &quot; the , , , , . . . . . . . <EOS>
#
# > हेलो ३
# = Halo 3
# < member bahadur <EOS>
#
# > जो हर दावे की तरह सही या गलत निकल सकता है &#124;
# = which , of course , may or may not be true .
# < which is a a or or or or . <EOS>
#
# > विद ् यासागर इंस ् टीट ् यूट ऑफ मेंटल हेल ् थ ऐंड़ न ् यूरो साइंसेज ( विमहांस ) और इंड़ियन साइकियाट ् रिक सोसाइटी का हाल ही में दिल ् ली में आयोजित सेमिनार इससे जुड़ी भ ् रांतियों को दूर करने का ड़ॉक ् टरों का एक प ् रयास है .
# = A recent seminar in Delhi organised by the Vidyasagar Institute of Mental Health and Neuro Sciences -LRB- VIMHANS -RRB- and the Indian Psychiatry Society is part of the effort by doctors to remove misconceptions .
# < the the of of of of , of , the , the the , the the the , the the the , the the the , the , the the , the , the , the the the , the the , . the , . . . . . <EOS>
#
# > रमेश सिप ् पी
# = Ramesh Sippy
# < member bahadur bahadur <EOS>
#
# > प ् राण कुमार शर ् मा
# = Pran Kumar Sharma
# < ram sharma , the the of <EOS>
#
# > राजन और साजन मिश ् रा
# = Rajan and Sajan Mishra
# < rukmini and the and and and <EOS>
#
# > भौतिकी के सम ् पूर ् ण सिद ् धान ् त जो हमारे पास हैं
# = All the theories in physics that we have today
# < the the the the the , , , , , , , , , of the <EOS>
#
# > पता पुस ् तिका
# = Address Book
# < address address address address <EOS>
#
# > आखन विश ् वविद ् यालय
# = RWTH Aachen University
# < 2nd gandhi gandhi , the united states <EOS>
#
# > कर तथा बेनिफिट में सुदारों के साथ साथ , नैशनल मिनिमम वेज ( राष ् ट ् रीय न ् यूनतम वेतन ) से काम करने का लाभ व ् यक ् त हुआ है और लोगों को प ् रोत ् साहन मिला है कि वे बेनिफिट ् स से हटकर काम करने की ओर बढें , और &#124;
# = together with tax and benefit reforms , the national minimum wage has helped to make work pay and encourage individuals to move from benefits into work ; and
# < the the , the and and and and and and and the and and the and the and the the and the the and the the the the the the the the the the the the the the the the the the the the the the . , . , . <EOS>
#
# > स ् वामी चिन ् मयानंद
# = Chinmayananda Saraswati
# < 2nd terrorism terrorism terrorism terrorism terrorism <EOS>
#
# > आरएक ् सवीटी
# = RXVT
# < print tagore bahadur <EOS>
#
# > आपातकालीन चिकित ् सकों के दल ने उस रोगी के लिए नेत ् र चिकित ् सक को बुलाने का निर ् णय किया जिसे दुर ् घटना में आंख पर चोट लगी थी ।
# = The team of emergency doctors decided to call an oculist for a patient who suffered eye injury in the accident .
# < in the , of to the to the to the to the to the to the to the the the the the the the the the the the the the . . <EOS>
#
# > संयुक ् त अरब अमीरात
# = United Arab Emirates
# < group of &#91; member &#93; <EOS>
#
# > अग ् रेषित शैली ( F ) :
# = Forward style :
# < exclude carbon-copy : : <EOS>
#
# > हम जानते हैं क ् योंकि यह ऐसा कहता है
# = We know because it says so
# < we we , the the the the the <EOS>
#
# > आतंक के शिकार थे
# = the horror , everybody .
# < member cassiopeiae sharan de <EOS>
#
# > रद ् द किया
# = Canceled
# < redo trash <EOS>
#
# > जो कि एक नई खोजी गई भाषा है
# = which is a newly-discovered language .
# < a new , a a a <EOS>
#
# > संयोजन करें
# = Connect
# < member singh <EOS>
#
# > ( तालियाँ )
# = ( Applause )
# < ( laughter ) <EOS>
#
# > बर ् गर किंग ् स
# = Burger King
# < guru guru burning de with the consolidated <EOS>
#
# > { 0 } को नष ् ट नहीं कर सका
# = Could not delete { 0 }
# < could not delete { 0 } { } } <EOS>
#
# > घर - स ् कूल के बीच के समझौते द ् वारा आपको इसकी याद दिलाई जानी चाहिए &#124; भाष ् ;
# = Home-school agreements should remind you of this .
# < if you want to the to the to the . the . the . the . . . . . . . . . <EOS>
#
# > खिमसार जोधपुर और बीकानेर के मार ् ग के मध ् य स ् थित हैं .
# = khimsar is located on the route between jodhpur and bikaner .
# < the the , of the , the , the the , the the and the . . . . <EOS>
#
# > मै अभी आपको एक कहानी सुनाने वाली हूँ .
# = Now I &apos;m going to give you a story .
# < the story of the story of the story . <EOS>
#
# > गाइड
# = Guide ( film )
# < bhasa <EOS>
#
# > जयपुर इण ् डियन एयरलाइन ् स की नियमित उडानों द ् वारा दिल ् ली , मुम ् बई , अहमदाबाद से भलीभांति जुडा है .
# = jaipur is well connected to delhi , bombay , and ahemadabad through regular flights of indian airlines .
# < the the , , , , , , , , , , , , , , , , , , , , , , , . <EOS>
#
# > 50 आवेदनपत ् र थ ् फ ् 1 और थ ् फ ् 1ध ् के अंत में दो
# = 50 . There are two declarations at the end of the WP1 and the WP1X application forms .
# < in the , , , , , , , , , , , , , , , united states , and the united states . <EOS>
#
# > सिपहसालर को लगा कि उसकी मौत के बाद पत ् नियां दोबारा शादी कर लेंगी , सो उसने उन ् हें मारने का फैसल किया .
# = Fearing that his wives would remarry after his death , the anxious general chose to kill them .
# < the the , the , the , , , , , , , , , the the , the , . <EOS>
#
# > जीपीडब ् ल ् यू
# = Jeep
# < hans the of the of <EOS>
#
# > अगर आप ऋण ले रहे हैं , तो उसे अदा करने की रकम जोड़ लीजिए .
# = If you are taking out a loan , add on the repayments .
# < if you , the , , , , , , , , , , . <EOS>
#
# > इनको खराब करने में दूसरा प ् रमुख भागीदार है विद ् युत लेपन उद ् योगों का कचरा जो अक ् सर कारखाने के परिसर में ही इकट ् ठा किया जाता है .
# = Another major contributor is electroplating wastes which are normally stored inside the factory premises .
# < the , , the , the , the , , the , , , the , the , the , , , the , the , the the the the the the . . . <EOS>
#
# > सर ् वर तक पहुँच सम ् भव नहीं है , पंचांग केवल-पठन मोड में खोला गया है . त ् रुटि संदेश : % s
# = Server is unreachable , calendar is opened in read-only mode . Error message : % s
# < after of of , , , , , , , , , , , , , , , , , , . . . . . <EOS>
#
# > कोशी अंचल
# = Kosi Zone
# < saint bahadur <EOS>
#
# > नॉर ् थ ऐक ् टन
# = North Acton tube station
# < hip , and and <EOS>
#
# > { ० } को बिल ् ड पुस ् तिका में डालने में समस ् या
# = Problem moving { 0 } to the build folder
# < delete the the the the the the { url } to { { } } <EOS>
#
# > श ् रेणी : उत ् तर प ् रदेश का भूगोल
# = Class : Map of Uttar Pradesh
# < tel : the of of of of of of of of <EOS>
#
# > चयनित राष ् ट ् रपति का आधिकारिक जालस ् थल
# = The plan of the elected president
# < official of the the the the the the the parliament of the the <EOS>
#
# > Área de notificación
# = Notification Area
# < member bahadur <EOS>
#
# > स ् कोरर अंपायर के हाथ के संकेतों द ् वारा निर ् देशित होते हैं.उदाहरण के लिए अंपायर एक तर ् जनी अंगुली उठा कर बताता है की बल ् लेबाज आउट हो गया है ; और यदि बल ् लेबाज ने छ : रन बनाए हैं तो वो दोनों हाथों को ऊपर उठाता है .
# = The scorers are acknowledged by umpire &apos;s arm signal . For example if a batsman is out then the umpire signals by pointing his one finger upright , and if the batsman hits 6 run then the umpire signals by uprighting both his hands in air .
# < the the of of of of , of the of , the the of the of the of the of the the the the the the the the the the the the the the the the the the the the the the the the , the , . , . . . <EOS>
#
# > प ् रोफ ़ ाइल
# = Profile
# < the the the data <EOS>
#
# > कॉफ ़ ी
# = Coffee
# < simon of <EOS>
#
# > यह साथी इमारतें 1643 में पुरी हुईं ।
# = These outlying buildings were completed in 1643 .
# < this was the of of of of of <EOS>
#
# > हमें जळ से जळ यह जान लेना होगा कि ऐसा चाहने वाल कौन है .
# = We need to know who was responsible and we need to know urgently .
# < the the of the the the the the the , the the the . . <EOS>
#
# > युद ् ध के दौरान वीरांगना ने अनुभव किया कि उसे मारने की नहीं वरन बंदी बनाने का प ् रयास किया जा रहा है तो उसने वहीं आत ् महत ् या कर ली ।
# = Bold lady realize at the time of battle that she is not to be kill but trying to make her slave.so she has suicide on spot .
# < the the of of of , , , the , , , , , , , , , , , , , , , the the the the the . . <EOS>
#
# > नारफाक द ् वीप
# = Norfolk Island
# < the chandra k. <EOS>
#
# > गमभन : ओंकार जोशी का भारतीय भाषा शब ् द-संसाधक ( WYSWYG )
# = gambhan : indian language word processor of omkar joshi ( WYSWYG )
# < gambhan of languages of indian languages : indian languages ( indian languages ) <EOS>
#
# > तो ऐसा करते हैं कि --- मैने ये सारा प ् रशिक ् षण दिया ,
# = so let &apos;s -- I did all this training .
# < so we the the , , , , , , , <EOS>
#
# > अमान ् य फ ़ ाइल नाम
# = Invalid file name
# < invalid name id id of the history <EOS>
#
# > क ् या आप और आप का जीवनसाथी :
# = Have you or your partner :
# < you may you and and and <EOS>
#
# > हाल के सर ् वर ( R )
# = Recent Servers
# < current current current ( &#91; server ) <EOS>
#
# > यहाँ यह
# = This here
# < somewhere <EOS>
#
# > हालाँकि मैं बुश को पसन ् द करता हूँ और उनके विषय में अच ् छा सोचता हूँ पर मैंने कट ् टरपंथी इस ् लाम के प ् रति उनकी प ् रतिक ् रिया की आलोचना 2001 से ही की है , 2002 से उनकी अरब इजरायल नीति की , 2003 से उनकी इराक नीति की और 2005 से उनकी लोकतांत ् रिक नीति की । वर ् ष 2007 और 2008 में मैंने उनके समस ् त मध ् य पूर ् व के प ् रयासों की कमियों की समालोचना की ।
# = While I like and think well of Bush , I have criticized his response to radical Islam since 2001 , his Arab-Israeli policy since 2002 , his Iraq policy since 2003 , and his democracy policy since 2005 . In both 2007 and 2008 , I critiqued the shortcomings of his overall Middle East efforts .
# < the the , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , the , the the the the the the the . . . <EOS>
#
# > इसलिए भारतीय साहित ् य एवं सिनेमा ने अकबर से प ् रेरित कई पात ् र रचे गए हैं ।
# = That is why Indian literature and cinema has created many characters inspired by Akbar .
# < he was the indian of indian the , , , of , of , of the of indian the . <EOS>
#
# > फिर उसने हरेक व ् यक ् ति से अपने पहरेदारों समेत कहा कि वे अपने हथियार उन लोगों के हवाले कर दें , जिन ् हें कबीले के सरदार ने नियुक ् त किया है ।
# = Then he asked that everyone , including his own sentinels , hand over their arms to the men appointed by the tribal chieftains .
# < in the , of , the the , the , , , the , , , the , , the the , the , the , , , , , , , the . . . <EOS>
#
# > सामान ़ ् य प ् रसव लगभग 45 मिनट में पूरा हो जाता है .
# = In normal delivery , the whole thing is completed in about 45 minutes .
# < the the the the the the the the , months of the the the <EOS>
#
# > जबकि यह निर ् णय विशेषज ् ञ लोगों के द ् वारा लिया जाता था &#124;
# = even when judged by the most expert people .
# < the were the the to the the the the the the the to . . <EOS>
#
# > हनुमान ने लंका की ओर प ् रस ् थान किया ।
# = Hanuman to Lanka and departure
# < the the of , the , the the . . . <EOS>
#
# > इस प ् रकार का मत शुद ् ध रूप से बहु-ईश ् वरवादी कहा जा सकता है ।
# = This type of opinion can be said to be Polytheism .
# < this this of the of of , of , the the the of , the the <EOS>
#
# > उछलती कुंजी टाइपिंग विलंब
# = Bounce keys typing delay
# < j. sharan gandhi mission <EOS>
#
# > सो.सीएल
# = So.cl
# < so.cl <EOS>
#
# > भाषा पट ् टी पर इनपुट विधि नाम दिखाएँ
# = Show input method name on language bar
# < start the name page to the the page <EOS>
#
# > स ़ ् वतंत ् रता और समानता के उपयुक़ ् त संतुलन पर आधारित समाज में संस ़ ् कृति को सार ् वलौकिक मानवीय मूल ़ ् यों की समन ़ ् वयात ़ ् मक अभिव ़ ् यक़ ् ति मानना चाहिए जो सभी व ़ ् यक़ ् तियों , ऊंचे या नीचे , धनवान या गरीब तथा सभी की पहुंच के अंतर ् गत हैं , लागू होते है .
# = In a society based on a proper balance of freedom and equality , culture should be regarded as a harmonious expression of universal human values common to all men , high or low , rich or poor , and should be within the reach of all .
# < the of of of of of of , of all the , , , , , , , , of the , , , , , , , , , , , of , , , , the , , , the , , , , , , , , , , , , , , , , , , , , , , , , , , , . . . <EOS>
#
# > यह है कि लोग भ ् रष ् टाचार , भ ् रष ् टाचार के बारे में बात कर रहे हैं ।
# = That is that people talk about corruption , corruption .
# < it is the of the of , the , , , , , , , , , , of the . <EOS>
#
# > पिछले कुछ समय से , इस क ् षेत ् र में देश की बहुमूल ् य विरासत को वर ् तमान और भावी पीढ़ियों के लिए बचाने , उनका संग ् रह करने और उनके संरक ् षण के लिए सभी आवश ् यक संसाधनों को प ् रयोग में लाने के प ् रयास किये जा रहे हैं .
# = Of Jate , efforts are being made to harness all necessary resources towards salvaging , collecting and preserving for the present and future generations , the country &apos; s rich heritage in this area .
# < all the , , the , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , the the the the the the the the the the , , , , . <EOS>
#
# > यह अप ् रवाहित जल का छोटा सा द ् वीप विश ् व के विभिन ् न भागों से आने वाले सैकडओं विरले प ् रवासी पक ् षियों का बसेरा है .
# = this little island on the backwaters is a favorite haunt of hundreds of rare migratory birds from different parts of the world .
# < the of of of the of the of the the the the the the the the the the the the the the the the the the the the the the the the . . . . . <EOS>
#
# > ओह , यह दुखी है &#124;
# = Oh , it &apos;s so sad .
# < oh , , , , , <EOS>
#
# > जिससे कि आप समझ सकें कि हम क ् या कर रहे हैं ।
# = so you can see what it is that we &apos;re doing .
# < we we get to the the the the the the . . <EOS>
#
# > लेकिन राजनीतिक सौमनस ़ ् य बरतरफ , सुभाष को साफ लगता कि अनके अंग ् रेज दोस ़ ् त अनुदार दृष ़ ् टिकोण रखते हैं .
# = But , regardless of the lack of political rapport , even Subhas could count among his friends Britishers holding conservative views .
# < the the of of of , of , of , , the , the , the , the , the , , , , , , , . <EOS>
#
# > विकी डोनर
# = Vicky Donor
# < purchased <EOS>
#
# > नर ् क चतुर ् दशी
# = Naraka Chaturdashi
# < all of our terrorism , the <EOS>
#
# > जब में उनकी फोटो लेते हूँ ,
# = When I &apos;m photographing them ,
# < when we were when the , , <EOS>
#
# > पानीपत का द ् वितीय युद ् ध
# = Battle of Panipat ( 1556 )
# < 2nd members of the member and the <EOS>
#
# > अर ् जेन ् टिना
# = Argentina
# < j. sharan member – members <EOS>
#
# > घास फूस और कीट सरलता से उन ़ ् हें मिल जाते हैं.यही वस ़ ् तुएं उनका सामान ़ ् य भोजन भी हैं .
# = They can also have easy access to grasses and insects which are their natural food .
# < the the , the , the , the , the , the , the , the , , , , , , and <EOS>
#
# > &quot; संस ् करण &quot; विशेषता मेटासिटी विषय 1.xml या मेटासिटी विषय 2.xml में उपयोग नहीं किया जा सकता है .
# = &quot; version &quot; attribute cannot be used in metacity-theme-1.xml or metacity-theme-2.xml
# < the the of the the the the the the the the the the the the the the . . . . . . . . . . <EOS>
#
# > मानवीय रोबोट प ् रतियोगिता में &#124;
# = in the humanoid RoboCup competition .
# < like the , a the . . <EOS>
#
# > देखें और पढ ़ ें Tipping प ् वाइंट एक ऑस ् ट ् रेलियाई विज ् ञान दस ् तावेज ़ दुर ् लभ आम और खतरे में पड ़ े वन ् य जीवन पर ग ् लोबल वार ् मिंग के प ् रभावों के बारे में .
# = watch and read &apos; tipping point &apos; , an australian Science Document on effectof global warming on scare , common and endangered wildlife .
# < the the , of , of , of , the , the , the , the , the , the , , , , , , , , , , , , , , , , , , , , , , , and , . the . . . <EOS>
#
# > % s : आंतरिक बफर के ओवरफ ् लो होने का पता लगा , % d वर ् ण अधिक हैं
# = % s : Internal buffer overflow detected , % d characters exceeded
# < % d rate of % d d d % d % d % d % d d <EOS>
#
# > और यह 1970 में यूनाइटेड स ् टेटस का आय वितरण है ।
# = the income distribution of the United States , 1970 .
# < this is the of of of from the of of , of <EOS>
#
# > संगीतकार &#124; गीतकार &#124; प ् रगीतकार
# = composer &#124; songwriter &#124; lyricist
# < the the the the the the . <EOS>
#
# > जेकब ज ़ ूमा
# = Jacob Zuma
# < j. n. bahadur raided <EOS>
#
# > मरी , तुर ् कमेनिस ् तान
# = Mary , Turkmenistan
# < migrated all , the , , , <EOS>
#
# > नेत ् रहीन व ् यक ् ति के लिए कार बनाना था &#124;
# = is to develop a car for the blind .
# < the the to the to to the the the the to . . <EOS>
#
# > Lसलिए यह सोचा गया कि नेपा की क ् षमता की कम से कम एक और फैक़ ् ट ् री दूसरी पंचवर ् षीय योजना में लगनी चाहिए .
# = It was , therefore , contemplated that at least one more factory of the capacity of NEPA be constructed during the Second Five-Year Plan .
# < the of of the of the of the of of the of the of of the of the of the of the of the of of the <EOS>
#
# > इस ् टाइल से आपको लगता होगा वो जिस प ् रकार टाई पहनते थे
# = Style makes you think of the bow tie he might have worn
# < this is the to the , the , the the the the <EOS>
#
# > यह विश ् व के नये ७ अजूबों में से एक है और आगरा की तीन विश ् व सांस ् क ् रतिक धरोहरों मे से एक है ।
# = It is one of the 7 modern wonder of the worlds and among Agra &apos;s 3 world heritage sites .
# < this is not , of , , , , , , , , , , , , , , , , , of , of , of , . . <EOS>
#
# > 2 . जब कभी काम पे आती है तो बिना सुनवाई के बडी मात ् रा मे मामले निपटा देती है
# = 2 . Whenever there is rush load , large number of vedicts are declared without listining to agruments .
# < when the , of , , the , the , , , , , , the the the . . <EOS>
#
# > यूनाइटेड स ् टेट ् स
# = United States
# < from the from the of <EOS>
#
# > अपारदर ् शिता
# = opacity
# < metacity id <EOS>
#
# > अपराजित वर ् मन ्
# = Aparajitavarman
# < subhashbabu subhashbabu the returned of the <EOS>
#
# > इन ऊंचे फव ् वारों की
# = of towering jets
# < these of these were <EOS>
#
# > फ ़ ् रेंच कनाडाई
# = French Canadian
# < history of nehru singh <EOS>
#
# > अपने बच ् चे की पढ़ाई में मदद ।
# = Helping with your children &apos;s reading
# < our help of our children &apos;s children . . <EOS>
#
# > प ् लेलिस ् ट से एक ऑडियो सीडी बनाओ
# = Create an audio CD from playlist
# < invalid rate if cd , the audio cd and the <EOS>
#
# > ऑसेलॉट
# = Ocelot
# < leave <EOS>
#
# > इतिहास
# = History
# < history <EOS>
#
# > तेज ़ ाब ( 1988 फ ़ िल ् म )
# = Tezaab
# < hans bihari in the history of the <EOS>
#
# > GIF छवि में वैश ् विक रंगमैप नहीं है तथा एक फ ् रेम के अंदर स ् थानीय रंगमैप नहीं है .
# = GIF image has no global colormap , and a frame inside it has no local colormap .
# < the standard of the the the of the the the the the the the the the the the the the the . . . <EOS>
#
# > इसलिए उन ् होंने अपने भैया भाभी के साथ दार ् जिलिंग की यात ् रा की , जहां से भव ् य कंचनजंघा शिखर दिखता था , जो माउंट एवरेस ् ट के बाद दूसरा बड़ा हिमशिखर है .
# = So he accompanied his brother and sister-in-law to Darjeeling which commands the view of the magnificent Kinchinjunga peak , the next highest to Mt .
# < after the the of the the the the the the the , the , the , the , the , the , the , the , the , , , , , , , , . . . <EOS>
#
# > उसने देखा कि वह गंगा के किनारे नीचे की ओर सिर किए किसी चीज पर लटक रहा है .
# = The Kine rode to him and found him on the banks of the Ganges , hanging on something with his head downwards .
# < the the of the the the the the the the the the the the . . . . . <EOS>
#
# > Jít online
# = Go Online
# < member online <EOS>
#
# > शिवराज पाटिल
# = Shivraj Patil
# < sharan patil <EOS>
#
# > इस तरह वह बालक अधिकाधिक विचारशील और आत ़ ् मविश ़ ् लेषी होता चला गया .
# = Thus , the boy grew more thoughtful and introspective .
# < this was the the the the and the and the the and the the the . . <EOS>
#
# > बोर ् न एगेन शेल
# = Bourne Again Shell
# < implementing the of the of <EOS>
#
# > हल ् का प ् लम
# = Light Plum
# < and the of the of <EOS>
#
# > देख सकते है &#124;
# = the fog and rain .
# < death of the biography of the indian <EOS>
#
# > ॠष ् य ॠंग एक ॠषि की प ् रेमकथा ।
# = &apos;Rushyasrunga &apos; A love story of a saint .
# < this was the , of , , of . . <EOS>
#
# > जैव सूचना विज ् ञान
# = Bioinformatics
# < sort of science science science <EOS>
#
# > को बैटरि में भेजा जाता है ।
# = is diverted into the battery .
# < the the of of the the . . <EOS>
#
# > इसके लिये प ् रारूप ( F ) :
# = Format for :
# < hans carbon-copy carbon-copy : <EOS>
#
# > संस ् कृत भारत को एकता के सूत ् र में बाँधती है ।
# = Sanskrit binds the whole India in one thread .
# < subhashbabu became the of of of , of , india , the india of . . . <EOS>
#
# > हमारी बातचीत के दौरान
# = during our conversation ,
# < our our our our <EOS>
#
# > क ् या मुख ् य विंडो को शीर ् ष पर रहना चाहिये
# = Whether the main window should stay on top
# < the of of the the the or , the or or or or <EOS>
#
# > भारत में इस ् लाम
# = Islam in India
# < kala of india <EOS>
#
# > साहसिक कार ् यों के प ् रति गहन अभिरुचि के परिणामस ् वरूप वे अपने जीवन के अनेक पहलूओं में सफल रहीं .
# = She succeeded in several spheres of her life as a result of her strong penchant for adventure activities .
# < our our our our our , of of of of of of of of of of of the of the of of . . . <EOS>
#
# > हिंदी में तीन प ् रकार का साहित ् य मिलता है ।
# = In Hindi 3 type literature
# < the the of of of the of the of the the . . . <EOS>
#
# > उनके लिए उस ईश ् वर का कोई महत ् व ही नहीं है अगर वह सूर ् य के प ् रकाश में नहीं दिखता , अस ् पृश ् यों के हृदय में नहीं विराजता और समस ् त बंधनों से मुक ् त , निर ् बंध नहीं है .
# = He has no need of God if He is not in the light of the sun and in the heart of the untouchable and beyond all barriers .
# < the the of of , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , the the the the the , , , . , . <EOS>
#
# > न ् टङ ् की राष ् ट ् रीय उद ् यान
# = Ntangki National Park
# < all the the the the the the the the the the the <EOS>
#
# > गोआ वेल ् हा
# = Old Goa
# < yes yes <EOS>
#
# > वह दो बार भारत की प ् रधान मंत ् री चुनी गयीं ।
# = SHE WAS ELECTED TWO TIMES AS THE PRIME MINISTER OF INDIA .
# < he was the of , , , , , , the <EOS>
#
# > कर ् मकांड ( वेद ) से ज ् ञान ( उपनिषद ् ) की ओर आते हुए भारतीय मानस में पुराणों के माध ् यम से भक ् ति की अविरल धारा प ् रवाहित हुई है ।
# = In the minds of Indians who live though ritualistic part ( Vedas ) to the part that deals in Suprteme Knowledge ( Upanishads ) , the uninterrupted stream of Bhakti ( devotion to the Lord ) flows through the puranas .
# < the , , , , , , , , , , , , , , , , , , , , , , , ( , ) , . . . <EOS>
#
# > अमेरिका / उत ् तरीडकोटा / सेंटर
# = America / NorthDakota / Center
# < binary / / / / / / <EOS>
#
# > उसने गहरी साँस ली ।
# = He breathed out .
# < bihari babu was <EOS>
#
# > बहुत कम बार , बच ् चों को गंभीर एलर ् जीक परिणामों का सामना कोई टिका लेने के बाद करना पडता है ( तकरीबन 100,000 MMR के टिकों में 1 से )
# = Very rarely , children can have severe allergic reactions straight after any immunisation ( about 1 in 100,000 immunisations for MMR ) .
# < after the , children , the the , , , , , , , , , , , , , , , , , , , , , , , <EOS>
#
# > यूट ् यूब पर
# = On you tube
# < member of the biography <EOS>
#
# > ये काग ़ ज़ पर लिखी हुई पढ ़ ने की चीज़ होती है .
# = It &apos;s a sort of paper-based reader .
# < the the of of of the of the of the of the the the . . . . . . <EOS>
#
# > उसे खाने के लिए कुछ चाहिए ! &lt; s &gt; यह खयाल उसे कुछ मूर ् खतापूर ् ण , उपाहासास ् पद - सा जान पड़ा - लेकिन क ् या करे , ज़िंदगी ऐसी ही तो है ।
# = It was idiotic , it was ridiculous , but life is like that .
# < the , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , <EOS>
#
# > क ् या लटकता बटन संवेदनशीन है जब मॉडल रिक ् त है
# = Whether the dropdown button is sensitive when the model is empty
# < the of the of the of the of , of the of <EOS>
#
# > उसे उसके पद से राष ् ट ् रपति तभी हटा सकता है जब विशेष बहुमत से ( यानी प ् रत ् येक सदन द ् वारा उस सदन की कुल सदस ् य संख ् या के बहुमत से तथा उस सदन के उपस ् थित और मत देने वाले सदस ् यों के कम-से-कम दो तिहाई बहुमत से ) संसद के दोनों सदनों द ् वारा पारित समावेदन उसके सामने प ् रस ् तुत किया जाए &#91; अनुच ् छेद 124 ( 4 ) तथा 218 &#93; .
# = He can be removed from his Office by the President , only if a joint address passed by both Houses of Parliament with a special majority -LRB- i.e . , by a majority of the total membership of the House and by a majority of not less than two-thirds of the members of each House present and voting -RRB- is presented to him -LRB- article 124 -LRB- 4 -RRB- and 218 -RRB- .
# < -lrb- 16 -rrb- -lrb- 16 -rrb- -lrb- 16 -rrb- -lrb- 16 -rrb- -lrb- 16 -rrb- -lrb- 16 -rrb- -lrb- 16 -rrb- -lrb- 16 -rrb- , the house -lrb- 16 -rrb- , the house -lrb- f -rrb- -lrb- the -rrb- -lrb- i.e -rrb- -lrb- the -rrb- of the house -lrb- f -rrb- -lrb- the -rrb- of the house -lrb- f -rrb- -lrb- f -rrb- -lrb- the -rrb- -lrb- f -rrb- -lrb- the -rrb- -lrb- f -rrb- -lrb- f -rrb- -lrb- f -rrb- -lrb- f -rrb- -lrb- f -rrb- -lrb- f -rrb- -lrb- f -rrb- -lrb- f -rrb- -lrb- f -rrb- -lrb-
#
# > भार कम करने के लिए , एक सप ़ ् ताह में आधे से एक किग ् रा तक भार कम करने का उद ् देश ् य होना चाहिए और कई महीनों में आदर ् श भार तक पहुंचना चाहिए.प ् रतिदिन 1,200-1,500 कैलोरी ( कई बार कम कैलोरी वाला आहार चिकित ़ ् सक की देखरेख में लेना जरूरी होता है ) की संयमित कमी के लिए तीन बार संतुलित आहार लेने की सलाह दी जाती है.दो बार के भोजन के बीच में कुछ खाने और कार ् बोनेट वाले पेयों से बचना चाहिए .
# = To lose weight , the aim should be to lose half to 1 kg per week and come down to the ideal weight over several months . A moderate reduction to 1,200-1,500 calories per day -LRB- a lower calorie diet may be required in some cases under medical supervision -RRB- consisting of three well-balanced meals is advised . Eating between meals and use of aerated soft drinks should be avoided .
# < the should should be a to should of the to the to the to the , to the , to the , to the , to the , and , , , , , , , , , , , , , the the , , , , , , , , and the the , , , , , , , , , , , , , , , , , , , , , , and the the , , , , <EOS>
#
# > संदर ् भ
# = Reference
# < anthony subhashbabu tagore <EOS>
#
# > फिर तो अमेरिका में उनका बहुत स ् वागत हुआ ।
# = Thereafter he was welcomed everywhere in America .
# < then then , the the the , the the . . . <EOS>
#
# > हो सकता है आप कहें कि ये ठीक नहीं ,
# = You may say this is not fair ,
# < you may be , , , , , <EOS>
#
# > बान ् द ् रा-वर ् ली समुद ् रसेतु
# = Bandra – Worli Sea Link
# < death butting were butting , the were the the <EOS>
#
# > फ ़ ाइल नहीं खोल सकता है
# = Can not open file
# < open the file the <EOS>
#
# > पुरुष की ठेलागाड ़ ी
# = Man &apos;s Cart
# < the of of of <EOS>
#
# > मगर धीरे धीरे इन औरतों ने अपने हिसाब से बेचना सीख लिया ।
# = but over time , the women learnt to sell on their own way .
# < but the , , the the , the the the the the . . . <EOS>
#
# > अनुस ् मारक ईमेल :
# = Reminder Email :
# < network id : : <EOS>
#
# > 1 निर ् वाचन आयोग के पास यह उत ् तरदायित ् व है कि वह निर ् वाचनॉ का पर ् यवेक ् षण निर ् देशन तथा आयोजन करवाये वह राष ् ट ् रपति उपराष ् ट ् रपति संसदराज ् यविधानसभा के चुनाव करता है
# = 1 . This is responsibility of election commission to inspect , direct and organize the elections and take elections of president , sub-president , parliament and state assembly .
# < the the of of of of of of the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the . . <EOS>
#
# > इंद ् रवारुणी
# = Citrullus colocynthis
# < print tagore bahadur <EOS>
#
# > वास ् तविक प ् रसन ् नता साधन सुगमता , संपन ् नता या यशगान करने या सुनने से नहीं बल ् कि कुछ उपयोगी कार ् य करने से मिलती है ।
# = Real joy comes not from ease or riches or from the praise of men , but from doing something worthwhile .
# < after the , , , , , , , , , , , , , , , , , , , the , the , the , the , the <EOS>
#
# > जो इनके संपर ् क में आते थे और इनके बीच से सूखे रह कर गुजरते थे &#124;
# = who can interact and move through it without getting wet .
# < the the , of , , , , , , , , and and . . <EOS>
#
# > नीले प ् रकाश की एक चमक ,
# = a flash of blue light ,
# < a the , , , , , <EOS>
#
# > इसके अध ् ययन करने वाले छात ् रों को गणित विज ् ञान एवं अन ् य भाषाएँ ग ् रहण करने में सहायता मिलती है ।
# = for the students who has the knowledge of maths , science , and different language will be helpful
# < the our , , , , , , , , , , , , , , , , , , , , , , <EOS>
#
# > परमपावन करमापा : कल मेरा व ् याख ् यान है .
# = His Holiness the Karmapa : Tomorrow is my Talk .
# < after the , , , , , , , . . <EOS>
#
# > उनकी अपनी शारीरिक यंत ् रणा , शरीर की पीड़ा उन ् हें घड़ी भर चैन से बैठने न देती थी.दर ् द से छुटकारा नहीं .
# = His own physical suffering , the burden of a body tormented with pain , with little or no respite &apos; .
# < he took the the of , the the , the , the , , , , , , , , , , , , <EOS>
#
# > लेकिन पिछले दशक में बीजीएमएल में कोई वेतन वृद ् धि नहीं ही और मौजूदा वेतनमानों के आधार पर वीएसएस की वर ् तमान पेशकश खदानों के बंद होने के पहले की आखिरी पेशकश है .
# = But no wage increase has happened in BGML in the past decade , and the present VSS , computed on the basis of the unchanged wages , is decidedly the last offer of succour before the curtain is drawn on the mines .
# < the the of of of of of the of the of the , the , of the the the the the the the the the the the the the the the the the the the the . . . . . <EOS>
#
# > आपके जीवन में कोई ऐसा व ् यक ् ति जिसे आप पूरे दिल से प ् यार करते हैं ,
# = somebody in your life who you love with all your heart ,
# < all of the the of , of , of , of the , of , <EOS>
#
# > इसका न कोई केंद ् र है , न कोई अगुआ .
# = It does n &apos;t have a centre , it does n &apos;t have a helmsman .
# < the the of the the , , , the the . . . . . <EOS>
#
# > पार ् वती
# = Parvati
# < the de <EOS>
#
# > मैंने एक दिन देखा ,
# = I saw one day ,
# < who , a , , <EOS>
#
# > कल % l : % M : % S % p
# = Tomorrow % l : % M : % S % p
# < yesterday % % % : % % % % % % <EOS>
#
# > और वो इस डैशबोर ् ड को देखें ।
# = and they look at this dashboard .
# < and the the the , . <EOS>
#
# > दीवार के अंतराल वाले स ़ ् थानों में पूर ् ण विकसित कुभं पंजर मॉटिफ विमान वाले भाग में बने हैं , जबकि मंडपों पर वैसी ही अवस ़ ् थाओं में उत ़ ् कृष ़ ् ट रूप से उत ़ ् कीर ् णित तथाकथित &apos; सजावटी भित ् तिस ़ ् तंभ &apos; या वृत ् त स ़ ् फटिक-पंजर श ् रृंगधारी भित ् तिस ़ ् तंभ हैं किंतु वे आधार कुभं या पूर ् ण घटविहीन हैं .
# = The recessed wall spaces carry fully formed kumbha panjara motifs , in the vimana part , while in similar situations on the mandapas they are elaborately carved vritta sphathitas , the so called &apos; decorative pilasters &apos; , that is pilasters carrying on top a panjara crest , but devoid of the basal kumbha or purna ghata .
# < the the of of of of the , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , . <EOS>
#
# > आज मैं आप सब के साथ बाँटना चाहती हूँ ,
# = The story I wanted to share with you today
# < there &apos;s a , , , , , , , <EOS>
#
# > हमे सिर ् फ 400 के लगभग पता थे
# = we had only known about 400
# < our and of of the , , , <EOS>
#
# > आप एक हाथ देख सकते है : वे दाहिना है या बांया है ? बांये हाथ के लिये लाल बटण दबाये , और दाहिने हाथ के लिये हरा बटण दबाये .
# = You can see a hand : is it a left hand or a right hand ? Click on the red button on the left , or the green button on the right .
# < the the of , , , , , , , , , , , , , , , , , , , , , , , , , . <EOS>
#
# > विस ् तार निर ् देशिका को चुनें .
# = Select the extension directory .
# < the the the the the the the . . <EOS>
#
# > मानहानि
# = abase
# < alert <EOS>
#
# > गंगोत ् री तीर ् थ शहर से १९ कि.मी. उत ् तर की ओर ३८९२ मी . ( १२७७० फी . ) की ऊँचाई पर इस हिमनद का मुख है ।
# = Gangotri pilgrim spot , is 19 kms to the north of the city and 3180 meters high , at the top of Himnad
# < after this , the the of , the , the , the , the , the the , the , the ( of ) , . . <EOS>
#
# > आपका कूटशब ् द का समय खत ् म हो गया .
# = Your password has expired .
# < the the the the the the the the . . <EOS>
#
# > कुहनियों को घुटनों पर रखकर , ठुड ् डी को हाथ में टिकाए , वह चुपचाप दुपहर की उनींदी धूप में बैठा रहा ।
# = He sat on in the motionless heat of noon , his chin on his hand and elbows resting on his knees .
# < the the , of , , , , , , , , , , , , , , , , . <EOS>
#
# > सामाजिक सुधार का उसका कार ् यक ् रम भी अपेक ् षाकृत अधिक क ् रांतिकारी था .
# = Its programme of social reform also was much more radical .
# < the the of of of of the of the of the of to of to . . <EOS>
#
# > गैबोन का ध ् वज
# = Flag of Gabon
# < flag of san the <EOS>
#
# > सा &amp; धन
# = Too &amp; ls
# < &amp; javascript <EOS>
#
# > उन ् हें मुंशी प ् रेमचंद व नवाब राय नाम से भी जाना जाता है और उपन ् यास सम ् राट के नाम से सम ् मानित किया जाता है ।
# = He known both as Munshi Premchand and as Nawab Rai and is also called king of speech .
# < according to his guru , verma , verma , verma , verma , his ram , the , , , , , , , , , <EOS>
#
# > इसका मुख ् यालय माउन ् टेन विय ् वु कैलिफोर ् निया अमरीका मे है ।
# = Its head office is at Mountain View , California , America .
# < the the the the , , , , , , , , , , , , , . . . <EOS>
#
# > मौलाना सैय ् यद अहमद और मौलवी मुहम ़ ् म ़ ् द युद ् ध भूमि में गिर गये और इस ़ ् लाम राज़ ् य का अंत हो गया .
# = Maulana Syed Ahmad and Maulvi Mohammad fell on the battlefield and the &apos; Islamic State &apos; came to an end .
# < the war , the the and the and the and and the and the and and the and and the the and and the the and and and and . . . . <EOS>
#
# > मेथोडिज ़ ् म
# = Methodism
# < in the in the <EOS>
#
# > स ् थिति
# = Status
# < sleeping status <EOS>
#
# > यदि आपका बच ् च या बच ् ची इतना / इतनी बड़ा / बड़ी है कि वह इसे समझ सके तो वे उसे भी इस पर हस ् ताक ् षर को कह सकते हैं &#124; भाष ् ;
# = They might also ask your child to sign if he or she is old enough to understand it .
# < if you child or to or to or , children or , children or , children aged to or or or , or or or or or or or or or or or <EOS>
#
# > उनके पति कुंवर भोजराज उदयपुर के महाराणा सांगा के पुत ् र थे ।
# = Kunwar Bhojraj ( Prince Bhojraj ) , her husband , was the son of Maharana Sanga of Udaipur .
# < the the , of , of , , , , , of the . . . . <EOS>
#
# > हरिकेन कट ् रीना
# = Hurricane Katrina
# < rene de anand <EOS>
#
# > कुछ नहीं ( &amp; N )
# = &amp; None
# < &amp; print &amp; <EOS>
#
# > और वह लोकप ् रिय लाइव जर ् नल के तहत एक ब ् लॉग चलाता है .
# = and he runs a blog under the popular Live Journal .
# < and the , , the , , , , , , , , , , . <EOS>
#
# > यूएसएएफ
# = Unidentified flying object
# < leave <EOS>
#
# > ठीक है , आगे चलते हैं ।
# = All right , let &apos;s go .
# < after , , , , , . <EOS>
#
# > राजस ् थान , भारतीय राज ् य है , जो कि देश के पश ् चिमी भाग पर पाकिस ् तान के सीमा से लगा हुआ हैं .
# = rajasthan is the indian state which borders pakistan on the western side of the country .
# < the the , , the , the , , , , , , , , , the , the , the , the , the , . <EOS>
#
# > पहलू अनुपात जिसके साथ कर ् सर खींचना है
# = Aspect ratio with which to draw insertion cursor
# < sacrilege refused to the of with with the <EOS>
#
# > संदर ् भ URL
# = Referrer URL
# < timeline sharan id of <EOS>
#
# > आराम कुर ् सी पोजीशन
# = comfortable chair postion .
# < general position position position <EOS>
#
# > समय मे यह शहर अपने ह ् रिदय में इतिहास की पूर ् वकथा को जो तीन हजार वर ् षों से ज ् यादा समय फला फूला को छुपाता है .
# = in time the city conceals within its bosom annals of civilizations that flourished for more than three thousand years .
# < the , of the the of the , of the , the the the , the the the the the the the the the the the the the . . . . . . . . <EOS>
#
# > भारत में परमाणु उर ् जा
# = Nuclear power in India
# < india of india , india india <EOS>
#
# > एक राज ् य हवाई प ् रशांत महासागर के मध ् य में स ् थित है ।
# = A state Hawaii , is situated in the middle of pacific ocean .
# < the the , , , , , , , , , , the , the , the . . <EOS>
#
# > &apos; % s &apos; फ ़ ोल ् डर बनाने में त ् रुटि : % s
# = Error creating folder &apos; % s &apos; : % s
# < couldn &apos;t escape ` % s &apos; % s &apos; : % s &apos; : % s <EOS>
#
# > वीडियो आउटपुट मॉड ् यूल
# = Video output modules
# < delete video video video <EOS>
#
# > गद ् दियों की बेशभूषा बड़ी आकर ् षक है .
# = The Gaddi dress is very attractive .
# < the the of the the the the the the the . . <EOS>
#
# > ऐंटीनेटल क ् लिनिक या आपका फ़ैमिली डाक ् टर आपको किसी माहिर डाक ् टर के पास भेजेगा जो आपकी जाँच करने के बादइस रोग को संभालने या इलाज करने के बारे में आपको सलाह देगा &#124;
# = The antenatal clinic or your family doctor should refer you to a specialist for assessment and advice about managing or treating your own infection .
# < if you to or for or for or for or , children aged or , or for or for or , or or for or or or or or or or or or <EOS>
#
# > कोई अगला सवाल
# = No next question
# < next question <EOS>
#
# > इस तरह &#124;
# = Like this .
# < like this . <EOS>
#
# > एक आदर ् शवादी के रूप में उसने सामाजिक बुराइयों की ही नहीं बल ़ ् कि अपनकि ZZवर , लोगों की भी आलोचना की
# = As an idealist he criticised society and sometimes his own people for their shortcomings .
# < the of of , of , , , , , , , , , , , , , , , , , <EOS>
#
# > इसी तरह , 25000 पाउंड तक के क ् रेडिट समझौते के संबंध में अन ् य फीस , जैसे सर ् वे फीस यस दलाल को ऋण के लिए इन ् शयोरेंस प ् रीमियम के रूप में अदा की गई रकम भी वापस मिल सकती है , अगर आप अंत में ऋण नहीं लेते है
# = Similarly , other fees , such as a survey fee or insurance premium paid to the credit broker in connection with a loan that you do not eventually take up , are also refundable to you for credit agreements up to 25,000 .
# < for , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , . . <EOS>
#
# > क ् योंकि यही पिपा और सोपा का असली संदेश है ।
# = Because that &apos;s the real message of PIPA and SOPA .
# < after the , , , , , , and . <EOS>
#
# > सर ् नर अनुक ् रिया बहुत जल ् द समाप ् त हो गई .
# = Server response ended too soon .
# < the the the the the the the the , the the the the . . . <EOS>
#
# > कां-कां करना
# = quack
# < yammer <EOS>
#
# > ईरान पर आक ् रमण को तैयार रहो
# = In a declassified National Intelligence Estimate , Iran : Nuclear Intentions and Capabilities , the U.S. intelligence agencies announced last December , &quot; We judge with high confidence that in fall 2003 , Tehran halted its nuclear weapons program . &quot;
# < the the the the the the <EOS>
#
# > अनुच ् छेद 246 में व ् यवस ् था है कि संघ सूची की मदों के बारे में संसद को विधियां बनाने की अनन ् य अधिकारिता होगी , राज ् य सूची की मदों के बारे में राज ् य के विधानमंडल को विधायां बनाने की अनन ् य शक ् ति होगी और समवर ् ती सूची में शामिल मदों के बारे में संघ तथा राज ् यों के विधानमंडल , दोनों की विधान बना सकते हैं .
# = Article 246 lays down that the Union Parliament would have exclusive jurisdiction to make laws in regard to items in the Union List , the State Legislature would have exclusive power to make laws in respect of items in the State List and both the Union and State Legislatures could legislate in the area of items included in the Concurrent List .
# < the the of of of of of the , of , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , the , , of the . . <EOS>
#
# > उस समय , यानी 1895 के करीब , सरकार ने उन ़ ् हें जज बन जाने को कहा .
# = At this time , about 1895 , the government asked Badruddin to become a judge .
# < he was , the , the , the , the , , , , , , the . . <EOS>
#
# > मैं इन बच ् चों कोदेख रही हूँ जो स ् मार ् ट है लेकिन उन ् होने बुनियादी बातें नहीं सीखी है
# = I &apos;m seeing too many of these smart kids who haven &apos;t learned basic things ,
# < the of of of the of the of , of the , the the the the the , the , the the <EOS>
#
# > सरकार ने रेस रिलेशन ् ज़ ऐक ् ट 1976 ( नस ् ली सम ् बन ् धी अधिनियम ) में बहुत से मुख ् य परिवर ् तन लाये हैं &#124;
# = The Government has made a number of significant changes to the Race Relations Act 1976 .
# < the report of the the the of of of the the the the the the the the . the the the the . the . the . . . . . . . . . . <EOS>
#
# > डेटाबेस फाइल उपयोग करने केलिए राह
# = Path for database file to use
# < print data file data file <EOS>
#
# > अपकर ् ष
# = abase
# < guru guru <EOS>
#
# > परिवर ् तन - हत ् था कुर ् सी पोजीशन
# = Change- Hand chair position
# < the position of the the the the the the the <EOS>
#
# > देखें कि क ् या स ् थान दिखना चाहिए
# = Set if and how the spaces should be visualized
# < the should should should be should should be <EOS>
#
# > जहाँ हम सेवाओं और उत ् पादों को
# = where we can extend services and products
# < we we the the the and and <EOS>
#
# > इस दिशा में सूत ् रों की खोज के लिए आयोग ने लंदन से फैजाबाद तक की यात ् राएं की हैं .
# = The commission , on its part , has visited locations ranging from London to Faizabad in search of clues .
# < the the of of to the of to of to the , the the the , the the the the the the . . <EOS>
#
# > चट ् टानी आरोहण जटिल हो सकती है क ् योंकि इसमें की तत ् वों का पारस ् परिक प ् रभाव सम ् मिलित होता है , आप आपके उपकरण , आपका कौशल और यन ् त ् र कला .
# = rock climbing can become complex because it involves the interplay of many elements you , your gear , your skill and techniques .
# < the , of the the , the , the , the the , the the the , the the the the the the the the the the the the and the the the the . . . . . . <EOS>
#
# > उन ् होंने इस बात से इनकार किया कि आयोग तहलका प ् रकरण में आने वाले रक ् षा सौदों की गहराई से जांच कर रहा है , &apos; &apos; पैनल के सामने भत-सी सामग ् री मौजूद है , यह जांच के स ् थापित प ् रोटोकाल का पालन कर रहा है . &apos; &apos;
# = He denied that the commission was probing too deeply into the defence deals that figured in the spycam scam . &quot; The material before the panel is voluminous . It is adhering to an established protocol of inquiry . &quot;
# < he was the of of , of , of , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , . the <EOS>
#
# > मैं आज आपसे दो चीजों के बारे में बात करना चाहता हूँ :
# = What I wanted to talk to you about today is two things :
# < the the the , , , , , : : : : <EOS>
#
# > क ् या ब ् रैसेरो टूटी सांकेतिक कड ़ ी फिल ् टर करता है
# = Should brasero filter broken symbolic links
# < the the the of , the , the , , , the , the the <EOS>
#
# > बाहरी कड ़ ियाँ
# = External Links
# < external external links <EOS>
#
# > किन ़ ् तु उनकी नग़ ् नता और बाह ् य अस ़ ् वच ़ ् छता के प ् रभाव स ़ ् वरूप यह सामान ़ ् य विश ़ ् वास बन गया था कि जिसके जन ़ ् मलग़ ् न में शनि कुपित है , वह आगामी जन ़ ् म में दिगम ़ ् बर संत होगा .
# = But their nudity and their dirty outward appearance had created an impression that a man on whom Shani -LRB- Saturn -RRB- had cast his evil eye at this birth would be born as a Digambara saint in the next birth .
# < but the of of of , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , the , the , the , , , , , , . the . <EOS>
#
# > हालिया ( R )
# = Recent
# < end <EOS>
#
# > कैमरा से लिया गया तस ् वीर का वर ् ण समायोजित करें
# = Adjusts the hue ( color tint ) of the picture coming from the camera
# < board of the of the of the of the of <EOS>
#
# > सापेक ् षिक गति
# = Relative Movement
# < sonia speed of the <EOS>
#
# > किसी ऐसि सेवा को न दे पाना जो कि प ् रदान की जानी चाहिए थी &#124;
# = failure to provide a service that ought to have been provided &lt; s &gt; poor administration
# < the should not be be be be be , not . . . <EOS>
#
# > सभी कार ् डस ् खत ् म होने तक गुणन के संबंध में संख ् या ढुॅंढने के लिये कार ् डस ् को पलटीयें
# = Turn the cards over to find two numbers which multiply the same , until all the cards are gone .
# < all kinds of the the , the the the the the the the the the the the the the the the the the the <EOS>
#
# > परिणाम यह कि एक औसत मजदूर , जिंदा रहने के लिए जितना आवश ् यक है उससे भी कम पर जी रहा था .
# = The result was that the average worker lived below the margin of subsistence .
# < the demand for the the of the the the the the the the the the the the the the the . . . <EOS>
#
# > २७ मार ् च
# = March 27
# < march 27 march <EOS>
#
# > सिस ् टम तयशुदा
# = System default
# < how the the <EOS>
#
# > जब आहारीय नियंत ् रण ही पर ् याप ़ ् त न हो तो खायी जाने वाली औषधियां अथवा इंसुलिन इंजेक़ ् शन भी शुरू कर दिया जाते हैं .
# ...
# = When they are reading , all the children have copies of the same book .
# < when children children , children aged home , the children of the children of . children , . . . . . . . <EOS>
#
# > भारत में हनीमून पर जाने वाले दंपत ् तियों के लिए आनंददायी पहाडई बंदर भगवान , हनूमान को समर ् पित है जो एक तरह की विपरीतता हो सकती है जैसा कि हनूमान का अर ् थ है ब ् रह ् मचर ् य , परन ् तु जाखू पहाडई के लंबे , टेढएमेढए रास ् ते नौसिखियों द ् वारा वैवाहिक कला में प ् रयोग में लाए जाते है .
# = the hill as a delight for the honeymooners in india , is dedicated to the monkey god , lord hanuman which can be a kind of contradiction as hanuman stands for celibacy but the long , meandering pathways of jakhoo hill are utilized by the beginners in the art conjugality .
# < the the , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , . <EOS>
#
# > दिशा निर ् धारणः
# = Orientation :
# < kuomintang the meeting of the <EOS>
#
# > कालाभुरा रंग
# = sepia
# < member singh <EOS>
#
# > जब तक हम दूसरों के बारे में नहीं सोचते और उनके लिए कुछ नहीं करते हैं , तब तक हम खुशियों के सबसे बड ़ े स ् रोत को गँवाते रहते हैं .
# = Unless we think of others and do something for them , we miss one of the greatest sources of happiness .
# < when the , of , the the the the the the the the the the the the the the the the the the the the the the the the the the the . . . . <EOS>
#
# > स ् वचालित A ( 5 GHz ) B / G ( 2.4 GHz )
# = Automatic A ( 5 GHz ) B / G ( 2.4 GHz )
# < the current ( from ) the of ( of ( of ) ) <EOS>
#
# > ५ अप ् रैल
# = April 5
# < guru gandhi commission <EOS>
#
# > विश ् वासघाती
# = treacherous
# < the the <EOS>
#
# > उन ् ही के शब ् दों में यदि ३० वर ् ष पूर ् व मुझसे यह प ् रश ् न पूछे जाते तो ‎ मैं इनमें आधे भी उत ् तर नहीं दे पाता ।
# = In his words , if 30 years ago this questions are asked by me so i am unable to answered half of them .
# < according to the the , , , , , , , , , , , , , , , , , , , , , , , of , of , . . <EOS>
#
# > अंटार ् कटिक रेखा
# = Antarctic Circle
# < ram chandra chandra group <EOS>
#
# > मूल बात है कि साहित ़ ् य का कोई भी विद ् यार ् थी यह जानकर विस ़ ् मित हो जाएगा कि बसव और सहयोगी इतने लोगों को रचना की ओर प ् रेरित करने में समर ् थ हुए .
# = The real thing that astonishes any student of literature is that Basava and his colleagues were able to inspire so many people to take to writing .
# < the of of of of of of of , of , of , of the , of , of the , of the , of the , of , of the , , of the . of the . . of the <EOS>
#
# > नेटवर ् क का स ् वचालित कॉन ् फ ़ िगरेशन करें ?
# = Auto-configure networking ?
# < the of of of the of the of the of the of the <EOS>
#
# > दलल स ् ट ् रीट में बड़ै-बड़ें की हवा खराब होने की तीन वजहें हैं .
# = Three factors explain this unprecedented pounding of the high and mighty on Dalal Street .
# < the the of of , , , , , , , , , , . <EOS>
#
# > यदि आप राष ् ट ् रीय उद ् यान की टोह लेने के प ् रति अधिक रुचि रखते हों तो बेहतर होगा कि ज ् यादातर मार ् गों तक अपनी पहुच सुनिश ् चित करने के लिए शुष ् कतर मौसमों को लक ् ष ् य बनाया जाए .
# = if you are more interested in exploring the national park , it is better to aim for drier seasons in order to ensure access to the majority of trails .
# < if the the of the the the the the the the the the the the the the the the the the the the the the the , the the the , the the the , the the the the the the the the the the the the the the <EOS>
#
# > एक अध ् ययन-सूची भी उपलब ् ध है .
# = A reading list is available .
# < a special the of a of of of of . <EOS>
#
# > जहाँ तक हो सके , एक गरम से ठंडे कमरे में न जाना ही उत ् तम रहेगा ।
# = If it is necessary to enter a cold room don &apos;t forget to wear a sweater or scarf .
# < the the of , , , , , , , , , , , , . <EOS>
#
# > श ् रेणी : Fear
# = Category : Fear
# < hans : : : <EOS>
#
# > ऊपर शिखर भी वर ् गाकार रहा होगा .
# = The sikhara on top also appears to have been square .
# < the the the the the the . . . . . . <EOS>
#
# > 3 . न ् यायधीशों हेतु कोई सेवा नियम नहीं है
# = There is no service rule for the judges .
# < the of of of the of the of the of <EOS>
#
# > चूकिं वे शांत व ़ ् यापारी के रूप में आये थे , हिंदू राजाओं और उनकी प ् रजा ने उनका स ़ ् वसागत किया और उन ़ ् हें न केवल अपने धर ् म को व ़ ् यक़ ् त करने तथा पालन करने की , बल ़ ् कि उसके प ् रचार और शिक ् षा देने की भी पूर ् ण स ़ ् वतंत ् रता दे दी .
# = Since they had come as peaceful traders they were well-comed by the Hindu rajas and their subjects , and were given full freedom not only to profess and practise their religion but also to preach and propagate it and they made full use of their freedom .
# < the the of of of , of , of , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , and , , , , , , . <EOS>
#
# > ये फव ् वारे असल में गीज ़ र ् स हो सकते हैं ,
# = that these jets might in fact be geysers ,
# < the the , , , , , , , , , , , , <EOS>
#
# > नेटवर ् क प ् रभाव
# = Network effect
# < impact of the the the the <EOS>
#
# > आरागोन
# = Aragon
# < leave <EOS>
#
# > अंतर ् राष ् ट ् रिय समुदाय से
# = from the international community
# < the the the the of the of of the of <EOS>
#
# > और वह पेपर टावल खरीद रहा है .
# = and he &apos;s shopping for some paper towels .
# < and he was the the . . . <EOS>
#
# > प ् रस ् थिति बार
# = StatusBar
# < the the the the indian <EOS>
#
# > नशीली दवाईयंो से सम ् बन ् धित समस ् याओं का सामना करने वालें जो भी व ् यक ् ति सहायता की तलाश कर रहे है , उनके लिए यहां विभिन ् न प ् रकार की सेवायें उपलब ् ध हैं ।
# = Lots of services are available for those who need help with drugs problems . .
# < the of of of of of , of , of , of , of the the the the the the the the the the the the of the the and the . . <EOS>
#
# > नॉर ् थ केंसिंग ् टन
# = North Kensington
# < north of and of , and <EOS>
#
# > राजपूत
# = Rajputana
# < leave <EOS>
#
# > यदि सूई लगाने के उपकरण जीवाणु रहित न किए गए हों और साझे तौर पर काम में लाए जाएँ तो संक ् रमण का होना ।
# = Infection where injecting equipment is unsterile and shared .
# < if the , if the , the the the the the the the the the the the and the the the . . <EOS>
#
# > दूसरी बड़ी लड़ाई की संभावना पर बाद में विचार किया गया.इस सिलसिले में कांग ् रेस ने दूसरे महायुद ् ध के शुरू होने के बारह बरस पहले सन 1927 में पहली बार अपनी नीति जाहिर की .
# = The possibility of another large-scale war was later considered , and in 1927 , twelve years before World War II actually started , the Congress first declared its policy in regard to it .
# < after the , the of the , the , the , the , the the the the the the the the the the the the the the the the the the the the . . . . . . . . <EOS>
#
# > शेरवानी
# = Sherwani
# < leave <EOS>
#
# > कड ़ ी पाठ
# = Link Text
# < network text text <EOS>
#
# > उसके साथ कलाकारों का समूह भी होता है जो गायन में और ताल में मंजीरे , खंजरी तथा उडुक ् की बजा कर साथ देते हैं .
# = There is also a chorus which keeps him company in song and rhythm , giving time with clappers , cymbals and the udukkai .
# < the , , , , , , , , , , , , , , and , and , and , of the . . <EOS>
#
# > १९९१ उत ् तरकाशी भूकम ् प
# = 1991 Uttarkashi earthquake
# < member of the the the the <EOS>
#
# > इन परिस ़ ् थितियों में यह आश ़ ् चर ् यजनक नहीं है कि अधिकांश महिलाएं इतनी बुद ् धिमान या जानकार नहीं थीं कि उनसे बातचीत भी की जा सके .
# = Under these circumstances it is not surprising that most women were in fact , not intelligent enough , or not informed enough to be worth talking to .
# < the the of the the the the the of the the the the the of the the the the the the the the the the the the the the the the . . . . <EOS>
#
# > कोई यह भी नहीं कह सकता थ कि चूंकि डेलीगेटों ने मुझे सदर चुना है , इसलिए यह कांग ् रेस समाजवादी बन गयी है .
# = No one could say that the Congress had turned socialist because the delegates had elected me their President .
# < it was a of the of of of of of , of the of the , of the of the , . of . <EOS>
#
# > महिला : जब कि वे इतने छोटे हैं , उन ् होंने इतना अच ् छा काम किया है .
# = Woman : Even though they are so young , they have done such good work .
# < when the , , , , , , , , , , , , , , , the . . <EOS>
#
# > &gt; क ् या यह सच है कि अमेरिका आपके यहां भत अहम भूमिका निभाता है ?
# = Q . Is it true that America plays an important role in your country ?
# < q . the , , the , , , , the , the , <EOS>
#
# > विकिपीडिया : प ् रबंधक सूचनापट
# = Wikipedia : Administrators &apos; noticeboard
# < wikipedia : article wikipedia : article <EOS>
#
# > आइ एम अलाइव
# = I Am Alive
# < the the <EOS>
#
# > स ् थानीय फ ़ ोल ् डर
# = Local Folders
# < immigration this page from the page of this <EOS>
#
# > बसव ने स ़ ् पष ़ ् ट किया : व ़ ् यक़ ् ति किसी भी जाति का हो सकता है .
# = Basava declared , &quot; A man may belong to any caste .
# < the the of the the the the the the the the the the the the the the the the . . . . . . . <EOS>
#
# > नाम के आधार पर डेस ् कटॉप संगठित करें ( O )
# = Organize Desktop by Name
# < saint the ( of ( of ( s ) , ( ) <EOS>
#
# > Transcoding सक ् रिय करें
# = Activate Transcoding
# < ram burning - the the <EOS>
#
# > इनमें सुनील शेट ् टीं , अजय देवगन , अरबाज खान , अभिषेक बच ् चन , संजय दत ् त , जैकी श ् राफ , सैफ अली खान और अक ् षय खन ् ना शामिल हैं .
# = Sunil Shetty , Ajay Devgan , Arbaaz Khan , Abhishek Bachchan , Sanjay Dutt , Jackie Shroff , Saif Ali Khan and Akshaye Khanna will star .
# < the , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , . <EOS>
#
# > जब तक वे इस बात को स ् वीकार नहीं करते हैं , तब तक उनके सूँघना बंद करने की सम ् भावना कम है .
# = Until they accept this they are not likely to stop .
# < when the , the the , the the the the the the , the the the the the the the . . . . . . . <EOS>
#
# > स ् वर ् णिम राज ् य , कैलीफोर ् निया ने अपना नाम एक स ् पेनी उपन ् यास में सोने से भरे हुए एक काल ् पनिक द ् वीप से लिया है .
# = the golden state , california takes its name from a make-believe island filled with gold in a spanish novel .
# < the the , of , , the , the , the the the the , the the the the the the the the the the the the the the the , the , the the the . . . <EOS>
#
# > पूर ् वानुमान
# = Forecast
# < print tagore bahadur <EOS>
#
# > और यह , मुट ् ठी भर लोग ,
# = And these people , a handful of people ,
# < and that , , , , , , , <EOS>
#
# > नीरागोंगा
# = Mount Nyiragongo
# < leave <EOS>
#
# > हवामान तापक ् रम
# = Airflow Temperature
# < considers outgoing <EOS>
#
# > न ् यायिक सक ् रियता
# = judgment process
# < all of , the the the <EOS>
#
# > सभी को पुनर ् स ् थापित करें
# = Restore all
# < all all all of all of the <EOS>
#
# > स ् मृति
# = Memory
# < mexican of : <EOS>
#
# > वास ् तव में भाषाई लिपियों की सीमा के भीतर ही है ।
# = actually falls within the range of the linguistic scripts .
# < the , the the the the the the the the . . . <EOS>
#
# > विश ् वभर की तेल की आवश ् यकता पूरी करने के लिए जलयान जलमार ् गों से होकर तेल एक स ् थान से दूसरे स ् थान पर ले जाते हैं .
# = To cater to global requirements , ships carry oil across the waterways .
# < the the of the the the the the the the the the the the the the the the the the the the the the the the the the the the the . the . . . <EOS>
#
# > कल ् पना चावला करनाल हरियाणा भारत . में एक हिंदू भारतीय परिवार में पैदा हुई थीं ।
# = Kalpana Chawala was born in Karnal , Haryana , India in Hindu Indian family .
# < kalpana the , of , , , , , , , , , indian indian india . . <EOS>
#
# > एक तरह से बीच की स ् थीति में होंगे .
# = will be at some sort of cusp .
# < one of the a a the the the . . <EOS>
#
# > मैं भाग ् यशाली थी कि मैंने पुनर ् वसन केंद ् र में काम किया ,
# = I &apos;m fortunate enough to work in the rehab facility ,
# < the the of the , , , , , , , , , , <EOS>
#
# > यूरोप और एशिया के विशाल भूभाग के उस पार सोवियत इलाकों में इंसान की आजादी और समाज में बराबरी की नयी धारण को विरोधियों का सामना करना पड़ रहा था .
# = And right across a vast area in Europe and Asia , in the Soviet territories , a new conception of human freedom and social equality fought desperately against a host of enemies .
# < the the of the the the the the the the the the the the the the the and the the and the the and the the the the . . . . <EOS>
#
# > डार ् विन ( गैलापागोस )
# = Darwin Island
# < do configuration ( ( ) <EOS>
#
# > ट ् रैश
# = Trash
# < sort of the <EOS>
#
# > अनेक विश ् वप ् रसिद ् ध मनोरम पर ् यटन स ् थल इसकी गोद मे बसे हैं जो सैलानियों का स ् वर ् ग कहलाते हैं ।
# = Many Internationally popular tourist spots are located in his laps which are called as the paradise for tourists .
# < the from the of of of of the of , of the , the the , the the the the the , the the of the the . . . . <EOS>
#
# > इस कनेक ् शन का उपयोग करें इसके संजाल पर संसाधन के लिए ( o )
# = Use this connection only for resources on its network
# < this this this this this the the <EOS>
#
# > --- कोई युक ् ति नहीं ---
# = --- No Tip ---
# < some of the the the the <EOS>
#
# > लेकिन कम विविध होना
# = But being less diverse
# < age of age <EOS>
#
# > भारत में हिल स ् टेशन के रूप में देहरादून एक प ् रसिद ् ध सूचि वाले स ् कूलों की तरह दून स ् कूल और भारत के प ् रसिद ् ध शिक ् षण केन ् द ् र के रूप में वेलहेम ् स का भी घर है , भारत में सबसे ज ् यादा मांग वाले हिल स ् टेशन होने के बावजूद यह दून घाटी को उच ् चतम स ् तर के शिक ् षण केन ् द ् र के योग ् य बनाता है .
# = as a hill station in india , dehradun is also home to the famed schools of the order of doon school and welhams as elite centers of learning in india apart from being a much sought after hill station in india , they qualify doon valley to be a star class educational center .
# < the indian india , the the , , the , , , the , , , , , , , , , , , , , the , the , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , the the , the the the the the the the the the the the the the the . . . . . . . <EOS>
#
# > समतल
# = Flat
# < create <EOS>
#
# > फाइल भेजें ...
# = Send Files ...
# < accessibility ... <EOS>
#
# > सलेटी : सर ् वसुविधासम ् पन ् न आनलाइन देवनागरी- समर ् थ ( WYSWYG )
# = Gray : Having all facilities , on-line , Devanagari-competent ( WYSWYG )
# < hans sharan ( of of of , of , , , , , , , , , , <EOS>
#
# > अबू-यज़ीद अलबिस ़ ् तामी से एक बार किसी ने पूछा कि आपने सूफ़ी मत में इतना उच ़ ् च स ़ ् थान कैसे प ् राप ़ ् त किया , तो उसने उत ् तर दिया : ? मैंने अपने अहं को उसी प ् रकार त ़ ् याग दिया जेसे सांप अपनी केंचुली का त ़ ् याग करता है .
# = Abu-Yazid Albis &apos; ami once being asked how he had attained his stage in Sufism , answered : &quot; I cast off my own self as a serpent casts off its skin .
# < the the of of of , members , the , , , , , , , , , , , , , , the , the , , , the , the , the , the , the , the , the , the , the , the the the the the the . . . <EOS>
#
# > सात बहनों ( देवियों ) का बंटवारा कैलंग की भांति गद ् दी में शाZक ् ति रूप , उसके मंदिरों तथा विभिन ़ ् न स ़ ् थानों पर बसने और पराक ् रम संबंधी अनेक किवदंतियां सुनते को मिलती
# = The Seven Sisters The female counterpart of Kailang are said to be the seven sisters-who are looked upon as the incarnation of the goddess Shakti .
# < the of of and , and and and , and and and and and and and the , and the the and the the the the , the the the the the the the , the , the , . of . . . <EOS>
#
# > सारवा हिरण
# = Sarva the Elk
# < globular <EOS>
#
# > नालको
# = National Aluminium Company
# < puri <EOS>
#
# > अब विधेयक वापस लेने से राजनैतिक सत ् ता पर फिर से काबिज होने का उनका काम भत मुश ् किल हो गया है .
# = Now the withdrawal of the bill makes her task of regaining political control an uphill one .
# < he was the the the the the the the the the the the the the the the the the the . . . . . <EOS>
#
# > सिन ् द नदी
# = Sind River
# < corona river <EOS>
#
# > यहा पे नमूद किये गये नुकसान भुगतान अदालत कम कर सकता है अगर उसे यह लगता है कि किरायेदार य फिर किरायेदार के साथ रहने वाला कोई भी व ् यक ् ति , साबित करते है ( आदमी या फिर औरत ) तो उन ् हें पूरे नुकसान भुगतान कम किया जा सकता है .
# = The court may reduce the damages described here if it considers that the tenant &apos; s behaviour or the behaviour of anybody living with the tenant , justifies awarding him or her less than the full damages ;
# < if the , of , the , the , the , the , the , , , the , , , , , , , , , , , , , , , , , , , , , , , , , , , . . . <EOS>
#
# > और हम मनुष ् यों के लिए , और निश ् चित रूप से हम मुसलमानों के लिए ,
# = And for us human beings , and certainly for us as Muslims ,
# < and we we we the the , , , , we , we , <EOS>
#
# > श ् रेणी : दक ् षिण अमेरिका के प ् राणी
# = Category : Fauna of South America
# < kalyan : 0000 : south kapoor singh : south krishna : <EOS>
#
# 0.1481156033876317
